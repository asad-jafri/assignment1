# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('ny_times_countries_2000_2016.csv')
df.head()
# Out:
#    year      country  num occurrences
# 0  2000  New Zealand              364
# 1  2000      Bermuda              201
# 2  2000       Latvia               56
# 3  2000       Canada             3245
# 4  2000   East Timor              178

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('1Country Population, Land Area, Density.csv')
df1.head()
# Out:
#        Country Population (2020) Land Area (Km²) Density (P/Km²)
# 0  Afghanistan        38,041,750         652,230           56.94
# 1      Albania         2,854,190          28,748          104.61
# 2      Algeria        43,053,050       2,381,740           17.73
# 3      Andorra            77,140             468          163.84
# 4       Angola        31,825,290       1,246,700           24.71

# %%
import pandas as pd
import numpy as np

output = pd.merge(df, df1, left_on = "country", right_on = "Country", how = 'left')
print(output)
# Out:
#       year           country  num occurrences      Country Population (2020)  \
# 0     2000       New Zealand              364  New Zealand         4,917,000
# 1     2000           Bermuda              201          NaN               NaN
# 2     2000            Latvia               56       Latvia         1,912,790
# 3     2000            Canada             3245       Canada        37,589,260
# 4     2000        East Timor              178          NaN               NaN
# ...    ...               ...              ...          ...               ...
# 3970  2016  Christmas Island              199          NaN               NaN
# 3971  2016            Greece              767       Greece        10,716,320
# 3972  2016          Paraguay               56     Paraguay         7,044,640
# 3973  2016           Croatia              170      Croatia         4,067,500
# 3974  2016           Comoros                2      Comoros           850,890
#
#      Land Area (Km²) Density (P/Km²)
# ...

# %%
output = output.drop(columns=['Country'])

# %%
output.describe()
# Out:
#               year  num occurrences
# count  3975.000000      3975.000000
# mean   2008.046289       486.624403
# std       4.897939      1759.169235
# min    2000.000000         1.000000
# 25%    2004.000000        27.000000
# 50%    2008.000000       105.000000
# 75%    2012.000000       329.000000
# max    2016.000000     28896.000000

# %%
# %matplotlib notebook
print(output[['country', 'num occurrences']].corr())
output.plot.scatter(x='country', y='num occurrences')
frame1 = plt.gca()
frame1.axes.get_xaxis().set_visible(False)
# Out:
#                  num occurrences
# num occurrences              1.0
# <img src="data:image/png;base64,..." width="640">
